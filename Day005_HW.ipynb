# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')

response = r.text
data = json.loads(response)#5陣列格式
print(len(data),'筆')
#print(data[0].keys())#取出陣列裡的物件的key
for item in data[0].keys():
    print(item)
# Out:
# 30 筆
# id
# title
# excerpt
# anonymousSchool
# anonymousDepartment
# pinned
# forumId
# replyId
# createdAt
# updatedAt
# commentCount
# likeCount
# withNickname
# tags
# topics
# meta
# forumName
# forumAlias
# gender
# school
# replyTitle
# mediaMeta
# reactions
# hidden
# customStyle
# isSuspiciousAccount
# layout
# withImages
# withVideos
# media
# reportReasonText
# postAvatar

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

#title #createdAt #commentCount #likeCount

import json
data = json.loads(response)
#print(data)
for d in data:
    print(d['title'])
    print(d['createdAt'])
    print(d['commentCount'])
    print(d['likeCount'])
# Out:
# 有人願意收留可愛的橘貓嗎？
# 2020-01-08T06:59:54.115Z
# 41
# 346
# 我和我的臘腸狗朋友
# 2020-01-08T01:22:56.123Z
# 27
# 245
# ＃新年特價 打擊口臭&兼顧健康！Arrr 寵物營養潔牙棒🍖許一個毛孩幸福快樂的健康生活🥰
# 2020-01-08T11:00:18.088Z
# 11
# 210
# 充滿喵喵的早餐店
# 2020-01-08T02:27:06.121Z
# 17
# 60
# 不就洗個澡至於這樣嗎🤣
# 2020-01-09T00:22:59.907Z
# 2
# 57
# #刺蝟 #投票 連我家刺蝟都去投票了，那你呢？
# 2020-01-08T13:36:09.922Z
# 1
# 44
# 可愛又欠扁的主子們
# 2020-01-08T04:44:54.404Z
# 0
# 40
# 巨貓與小短腿
# 2020-01-08T12:59:28.546Z
# 4
# 35
# 協尋愛貓！⚠️⚠️
# 2020-01-08T13:38:41.094Z
# 0
# 33
# 貓貓之所以是貓貓
# 2020-01-08T03:04:46.057Z
# 2
# 22
# 請問這個倉鼠!!!(๑Ő௰Ő๑)
# 2020-01-08T08:08:21.118Z
# 6
# 19
# 小肥橘❤️
# 2020-01-08T14:03:13.767Z
# 1
# 18
# 有人想認養小黑貓嗎？
# 2020-01-08T08:56:32.175Z
# 3
# 17
# 急徵鏟屎官 #貓咪送養
# 2020-01-08T10:19:01.188Z
# 3
# 12
# 用選票支持動物的權益，關心羚獸醫師
# 2020-01-08T16:23:41.402Z
# 2
# 11
# 每天都很鬧事
# 2020-01-09T01:51:55.957Z
# 1
# 10
# 這種貓真的是讓人很想吸也很想抱著！！！
# 2020-01-08T07:39:51.822Z
# 7
# 10
# #請益 這是貓在咳嗽嗎？附影片
# 2020-01-08T03:19:49.570Z
# 5
# 10
# 獅子王辛巴跟X巴？
# 2020-01-07T18:31:38.131Z
# 2
# 10
# ...

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
#commentCount #likeCount
import requests
res = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
js = json.loads(res.text)
res1 = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
jsn = json.loads(res1.text)
p_total_Comm = 0
p_total_Like = 0
for item in js:
    p_total_Comm += int(item['commentCount'])
    p_total_Like += int(item['likeCount'])
print('熱門平均留言人數:',p_total_Comm/30,'熱門平均按讚人數:',p_total_Like/30)
np_total_Comm = 0
np_total_Like = 0
for item1 in jsn:
    np_total_Comm +=int(item1['commentCount'])
    np_total_Like +=int(item1['likeCount'])
print('非熱門平均留言人數:',np_total_Comm/30,'非熱門平均按讚人數:',np_total_Like/30)
# Out:
# 熱門平均留言人數: 6.3 熱門平均按讚人數: 48.9
# 非熱門平均留言人數: 2.2 非熱門平均按讚人數: 18.933333333333334
