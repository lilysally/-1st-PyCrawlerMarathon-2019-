# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## PTT 網頁爬蟲

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-meta-value').text)
    except:
        continue
# Out:
# [新聞] 雷納德領袖風範 瑞佛斯：就像沉默版賈奈
# 作者: lovea (lovea)
# [新聞] NBA》甜瓜急了？主動徵詢4隊加盟機會
# 作者: BeardSmallGG (我鬍SGG)
# [新聞] 影／接地氣MVP！野生柯瑞與民眾街場鬥牛
# 作者: dreamraidery (騫仔)
# [花邊] 杰倫布朗：必須帶著緊迫感打球
# 作者: PttGod (PttGod)
# [新聞] 庫茲瑪無緣出征世界盃 波總：少了他很可
# 作者: fack3170 (法克)
# [Live] 世界盃熱身賽 希臘 vs 多明尼加
# 作者: jack19931993 (三無少年)
# [專欄] 戰勝美國的背後 澳洲世界盃軍團來勢洶洶
# 作者: hvariables (Speculative Male)
# [BOX ] 世界盃熱身賽 USA 84:68 CAN
# 作者: achernarsw (倒立澳客)
# (本文已被刪除) [ninebride]
# [情報] Dwight Howard 成為湖人隊史第一位穿39號
# 作者: thnlkj0665 (灰色地帶)
# [情報] Howard將領日薪　待在名單上才有錢
# 作者: USAGI0423 ()
# [新聞] 湖人新約0保障！魔獸「日薪」曝光
# 作者: amancan (jerry)
# [花邊] KT父親：新賽季西決 是勇士對湖人
# 作者: MadK17672 (大釣哥)
# [花邊] 勇士新場館大通中心掛上「死亡五小」畫像
# 作者: s5880852 (鮪魚蛋餅)
# [情報]如何看待霍華德加盟湖人？奧尼爾：我不認
# 作者: VeryGoodBoy (很棒的男孩)
# [新聞] 勇士新球場啟用！KD慘被製圖嘲諷…釣出本
# 作者: USAGI0423 ()
# [公告] 板規v6.4
# [情報] 2019-20 自由球員市場異動 (表格 8/16)
# [情報] 2019-20 自由球員市場異動 (每日 文字)
# [公告] 樂透取消及未來不再開啟樂透
# 作者: Vedan (味丹)
# Fw: [徵圖] PTT小天使 之 每月29號 P幣雨圖
# 作者: ericf129 (☆小艾克★)

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」
# * ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/home-sale/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

# %%
import pandas as pd

info_all = []
for d in soup.find_all(class_="title"):
    try:
        url = 'https://www.ptt.cc/' + d.find('a')['href']
        # print(url)
        soup_2 = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        info = []
        for dd in soup_2.find_all(class_='article-meta-value'):
            info.append(dd.text)
        info_all.append(info)
    except:
        continue
df = pd.DataFrame(info_all, columns=['作者', '看板', '標題', '時間'])
df
# Out:
#                               作者         看板                             標題  \
# 0                   calqwe (安安安)  home-sale                [請益] 關埔要自備款準備幾成
# 1                    Vett (Vett)  home-sale           Re: [閒聊] 講白的，實坪制不好嗎?
# 2              facebrook (玩一場遊戲)  home-sale             [賣/台北/大安] 忠孝敦化高樓美宅
# 3                  humbler (獸人H)  home-sale      [新聞] 打炒房重拳闖關 平均地權條例拚1/9三讀
# 4             urexception (咻咻在這)  home-sale                     [請益] 車位 實登
# 5                   ppp123 (3p哥)  home-sale                 [閒聊] 量縮 價格還是很硬
# 6                 KrisNYC (Kris)  home-sale   Re: [新聞] 房市走向實坪制？ 房產業者：對中古屋市
# 7                      tfct (小尼)  home-sale        [閒聊] 德運京鼎是怎麼蓋到公設比才28%的？
# 8             junior020486 (軟蛋頭)  home-sale         Re: [請益] 桃園為何這波漲的比較客氣？
# 9                        AAAB ()  home-sale       [新聞] 抑制炒房 加拿大對外國人關上大門：兩年
# 10                       AAAB ()  home-sale       [新聞] 血洗投資客「禁預售換約」恐打折？學者：
# 11                   H2 (超級噴火龍X)  home-sale    Re: [閒聊] 德運京鼎是怎麼蓋到公設比才28%的？
# 12                 MiniArse (型男)  home-sale         Re: [心得] 連假新竹竹北預售屋看房分享
# 13                   NovaShin ()  home-sale    Re: [閒聊] 德運京鼎是怎麼蓋到公設比才28%的？
# 14          ceca (生活藝術大師￼ ￾ ￼N￼)  home-sale  Re: [新聞] 打炒房重拳闖關 平均地權條例拚1/9三讀
# 15         jpopo0543 (恰普 cha gu)  home-sale            [請益] 透天改小套房好出租和轉手嗎？
# 16  angel07 (Dark Moon Princess)  home-sale                [公告] 檢舉申訴申請管理辦法
# 17  angel07 (Dark Moon Princess)  home-sale              [公告] home-sale 板規
# 18  angel07 (Dark Moon Princess)  home-sale              [公告] 2020 過渡時期暫行律
# 19  angel07 (Dark Moon Princess)  home-sale                     [公告] 置底檢舉區
# 20  angel07 (Dark Moon Princess)  home-sale                 [公告] 板務宣導暨規定調整
#
#                           時間
# 0   Tue Jan  3 20:16:56 2023
# 1   Tue Jan  3 20:19:22 2023
# 2   Tue Jan  3 21:17:53 2023
# 3   Tue Jan  3 21:31:57 2023
# 4   Tue Jan  3 21:36:29 2023
# 5   Tue Jan  3 21:52:55 2023
# 6   Tue Jan  3 22:08:56 2023
# 7   Tue Jan  3 22:09:14 2023
# 8   Tue Jan  3 22:33:29 2023
# 9   Tue Jan  3 22:42:53 2023
# 10  Tue Jan  3 22:55:23 2023
# 11  Tue Jan  3 22:59:03 2023
# 12  Tue Jan  3 23:02:39 2023
# 13  Tue Jan  3 23:03:03 2023
# 14  Tue Jan  3 23:14:51 2023
# 15  Tue Jan  3 23:17:06 2023
# 16  Mon May  1 13:13:00 2017
# 17  Thu Jul 12 04:10:59 2018
# 18  Tue Oct 27 12:26:13 2020
# 19  Fri Aug 27 11:20:16 2021
# 20  Sat May 21 22:14:44 2022
